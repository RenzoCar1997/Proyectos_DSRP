# %% [markdown]
# ### Tarea 5
# Comente cómo aplica lo aprendido a su proyecto

# %% [markdown]
# - Dado que mi proyecto es un problema de clasificación (Determinar si una muestra de agua es potable o no a partir de los valores de sus características más comunes ph, dureza, salinidad, etc.) me apoyó en el uso de la estadistica descriptiva e inferencial:
#
#   - Se clasifica cada variable a estudiar como variable discreta o continua, lo cual permite hacer un mejor análisis.
#
#   - Para conocer las caracteristicas de cada variable a estudiar utilizo la estadística descriptiva para así conocer las medidas de tendencia central (media y mediana) y medidas de dispersión (varianza y desviación estándar) de cada variable.
#
#   - En mi proyecto aplico el concepto de correlación para determinar que tipo de correlación existe entre las variables de mi conjunto de datos. Lo cual se resume en un gráfica de correlación.
#
#   - Me apoyaré de intervalos de confianza para comparar las medias de cada una de las variables a estudiar.
#
#   - Utilizaré pruebas de hipótesis para determinar si existe normalidad en los datos de cada variable a estudiar.
